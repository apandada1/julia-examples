# %%
## Time for diagonalization
# New Chromebook 6.4s
# Oneplus Phone 6.9s
# MIT PowerPC 0.5s
# MIT PowerPC with MKL 0.23s
# Jasmine's Mac M1 max 0.32s

# %%
using Plots; using LinearAlgebra;

# %%
using MKL;

# %%
a=range(1,10,100);

# %%
plot(a,sin.(a))

# %%
N=2000;

# %%
b = randn(N,N);

# %%
for ii=1:N
    for jj=1:N
        b[ii,jj]=(sin(ii+jj^2)+sin(jj+ii^2))/2
    end
end

# %%
@time c=eigen(b);
# Out:
#   2.243586 seconds (1.00 M allocations: 433.939 MiB, 1.84% gc time, 32.83% compilation time)

# %%
eigenvalues=c.values;

# %%
scatter(1:N,c.values)
