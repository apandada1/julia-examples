# %%
using Plots; using LinearAlgebra;

# %%
a=range(1,10,100)
# Out:
# 1.0:0.09090909090909091:10.0

# %%
plot(a,sin.(a))

# %%
b = randn(2000,2000);

# %%
b = (b+b')/2;

# %%
@time c=eigen(b);
# Out:
#   7.141332 seconds (15 allocations: 92.271 MiB, 0.25% gc time)

# %%
eigenvalues=c.values;

# %%
scatter(1:2000,c.values)
